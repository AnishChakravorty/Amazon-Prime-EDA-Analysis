# %% [markdown]
# # <h2 style="text-align: center; color: LightBlue;">Amazon Prime TV Shows and Movies Analysis</h2>

# %% [markdown]
# ##### **Project Type**    - EDA
#
# ##### **Contribution**    - Individual
#
# ##### **Name -** Anish Chakravorty

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #### Overview
#
# This project presents an Exploratory Data Analysis (EDA) of Amazon Prime Videos U.S. content library, aiming to reveal trends, patterns, and actionable insights related to content distribution, audience preferences, and platform strategy. The analysis leverages two datasets: one detailing titles (movies and TV shows) and another providing credits information (actors, directors, etc.). By examining both categorical and numerical attributes, we seek to understand content trends, audience engagement, and strategic opportunities for content creators and the platform.
#
# #### Key Insights
#
# 1. **Content Distribution 📈**
#     Assessed the ratio of movies 🎥 to TV shows 📺 to understand the platforms content mix and its impact on audience engagement.
#
# 2. **Genre Trends 🎭**
#     Identified the most prevalent genres using bar charts 📊 and word clouds ☁️, highlighting viewer preferences and genre dominance.
#
# 3. **Release Year Patterns 📅**
#     Analyzed the addition of content over time, focusing on release years to pinpoint periods of peak production and platform growth.
#
# 4. **IMDb Ratings & Popularity 📈**
#     Explored the relationship between IMDb ratings and audience engagement (e.g., votes), using scatter plots 📉 to visualize how ratings influence popularity.
#
# 5. **Top Actors & Directors 🎬**
#     Determined the most frequently credited actors and directors, using visualizations to showcase key contributors and collaboration networks.
#
# #### Visualizations
#
# To effectively communicate findings, the following visualizations were utilized:
#
# - **Bar Charts & Histograms 📊:** For analyzing genre distribution and IMDb rating trends.
# - **Scatter Plots 📉:** To examine relationships between ratings and audience votes.
# - **Heatmaps 🔥:** To uncover correlations among key variables.
# - **Network Graphs 🕸️:** To visualize connections and collaborations among actors and directors.
#
# These visualizations provide a comprehensive understanding of the platforms content landscape, supporting data-driven decisions for content strategy and audience engagement.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/AnishChakravorty/Amazon-Prime-EDA-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The goal of this project is to perform an in-depth Exploratory Data Analysis (EDA) of Amazon Prime Video's content library. By analyzing the available data, we aim to uncover insights into content diversity, regional availability, trends over time, and audience preferences. Specifically, the analysis will focus on:
#
# 1. **Content Diversity**: Identifying the dominant genres and categories on the platform.
# 2. **Regional Availability**: Understanding how content distribution varies across different regions and countries.
# 3. **Trends Over Time**: Examining how the content library has evolved over the years in terms of release patterns and production trends.
# 4. **Audience Engagement**: Analyzing IMDb ratings, votes, and TMDb popularity scores to determine the most popular and highly-rated shows and movies.
#
# The insights derived from this analysis will help content creators, businesses, and data analysts make data-driven decisions to enhance user engagement, optimize content strategies, and drive subscription growth in the competitive streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to leverage data-driven insights to enhance Amazon Prime Video's content strategy and audience engagement. By performing an in-depth Exploratory Data Analysis (EDA) on the platform's U.S. content library, the aim is to:
#
# 1. **Understand Content Trends**: Analyze the distribution of movies and TV shows, genres, and release patterns to identify dominant trends and gaps in the content library.
# 2. **Optimize Audience Engagement**: Examine IMDb and TMDb ratings, votes, and popularity scores to determine factors influencing audience preferences and engagement.
# 3. **Enhance Content Diversity**: Explore the production countries and genres to ensure a diverse and inclusive content offering that caters to a wide range of audiences.
# 4. **Support Strategic Decisions**: Provide actionable insights to content creators and business stakeholders to improve content acquisition, production, and marketing strategies.
#
# Ultimately, the goal is to use these insights to drive subscription growth, improve user satisfaction, and maintain a competitive edge in the streaming industry.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
titles = pd.read_csv('titles.csv')
credits = pd.read_csv('credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
titles.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
titles.shape
# Out:
# (9871, 15)

# %%
credits.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Merged

# %%
df = pd.merge(titles,credits, on = 'id', how = 'outer')

# %%
#New Dataframe
df.head()
# Out:
#          id            title   type  \
# 0  tm100001  The Lucky Texan  MOVIE
# 1  tm100001  The Lucky Texan  MOVIE
# 2  tm100001  The Lucky Texan  MOVIE
# 3  tm100001  The Lucky Texan  MOVIE
# 4  tm100001  The Lucky Texan  MOVIE
#
#                                          description  release_year  \
# 0  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 1  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 2  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 3  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 4  Jerry Mason, a young Texan, and Jake Benson, a...          1934
#
#   age_certification  runtime                            genres  \
# 0               NaN       61  ['western', 'action', 'romance']
# 1               NaN       61  ['western', 'action', 'romance']
# 2               NaN       61  ['western', 'action', 'romance']
# 3               NaN       61  ['western', 'action', 'romance']
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (125354, 19)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125354 entries, 0 to 125353
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    125354 non-null  object
#  1   title                 125354 non-null  object
#  2   type                  125354 non-null  object
#  3   description           125163 non-null  object
#  4   release_year          125354 non-null  int64
#  5   age_certification     56857 non-null   object
#  6   runtime               125354 non-null  int64
#  7   genres                125354 non-null  object
#  8   production_countries  125354 non-null  object
#  9   seasons               8501 non-null    float64
#  10  imdb_id               119978 non-null  object
#  11  imdb_score            118987 non-null  float64
#  12  imdb_votes            118957 non-null  float64
#  13  tmdb_popularity       124800 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
duplicate_rows
# Out:
# Number of duplicate rows: 168
#               id                  title   type  \
# 20435   tm137955          Broken Dreams  MOVIE
# 20436   tm137955          Broken Dreams  MOVIE
# 20437   tm137955          Broken Dreams  MOVIE
# 20438   tm137955          Broken Dreams  MOVIE
# 20439   tm137955          Broken Dreams  MOVIE
# ...          ...                    ...    ...
# 108160   tm89134  The Gunman From Bodie  MOVIE
# 108161   tm89134  The Gunman From Bodie  MOVIE
# 108162   tm89134  The Gunman From Bodie  MOVIE
# 108163   tm89134  The Gunman From Bodie  MOVIE
# 108164   tm89134  The Gunman From Bodie  MOVIE
#
#                                               description  release_year  \
# 20435   Medical intern Robert Morley is distraught aft...          1933
# 20436   Medical intern Robert Morley is distraught aft...          1933
# 20437   Medical intern Robert Morley is distraught aft...          1933
# 20438   Medical intern Robert Morley is distraught aft...          1933
# ...

# %% [markdown]
# ### Removing Duplicates

# %%
df.drop_duplicates(["id"],keep='first',inplace=True)

# %% [markdown]
# ### Check if duplicate values remove or not

# %%
# Checking for duplicate rows after dropping
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
duplicate_rows
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
df.shape
# Out:
# (9868, 19)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6484
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8511
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2080
# person_id               1007
# name                    1007
# character               1916
# role                    1007
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9868 entries, 0 to 125353
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9868 non-null   object
#  1   title                 9868 non-null   object
#  2   type                  9868 non-null   object
#  3   description           9749 non-null   object
#  4   release_year          9868 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9868 non-null   int64
#  7   genres                9868 non-null   object
#  8   production_countries  9868 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9201 non-null   object
#  11  imdb_score            8847 non-null   float64
#  12  imdb_votes            8837 non-null   float64
#  13  tmdb_popularity       9321 non-null   float64
#  14  tmdb_score            7788 non-null   float64
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ## 2. ***Data Wrangling***

# %% [markdown]
# ### Handling Missing Values

# %%
# Handling missing values
# 1. `description` (object)
df['description'].fillna("No Description", inplace=True)

# %%
# 2. `age_certification` (object)
df['age_certification'].fillna("Unknown", inplace=True)

# %%
# 3. Fill NaN values in 'seasons' with 0 before converting to int
df['seasons'] = df['seasons'].fillna(0).astype(int)

# %%
# 4. `imdb_id` (object)
# Dropping the imdb_id column
df.drop(columns=['imdb_id'], inplace=True)

# %%
# 5. `imdb_score` (float64)
df['imdb_score'].fillna(df['imdb_score'].median(), inplace=True)

# %%
# 6. `imdb_votes` (float64)
df['imdb_votes'].fillna(df['imdb_votes'].median(), inplace=True)

# %%
# 7. `tmdb_popularity` (float64)
df['tmdb_popularity'].fillna(df['tmdb_popularity'].median(), inplace=True)

# %%
# 8. `tmdb_score` (float64)
df['tmdb_score'].fillna(df['tmdb_score'].median(), inplace=True)

# %%
# 9. `person_id`, `name`, `character`, `role` (object)
df['person_id'].fillna("Unknown", inplace=True)
df['name'].fillna("Unknown", inplace=True)
df['character'].fillna("Unknown", inplace=True)
df['role'].fillna("Unknown", inplace=True)

# %%
# Explode genres and production_countries 
df['genres'] = df['genres'].apply(lambda x: eval(x) if isinstance(x, str) else x)
df['production_countries'] = df['production_countries'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# Explode the genres and production_countries columns
df_exploded = df.explode('genres').explode('production_countries').reset_index(drop=True)

# Display the first few rows of the updated dataframe
df_exploded.head()
# Out:
#           id                        title   type  \
# 0   tm100001              The Lucky Texan  MOVIE
# 1   tm100001              The Lucky Texan  MOVIE
# 2   tm100001              The Lucky Texan  MOVIE
# 3  tm1000022  Boonie Bears: The Wild Life  MOVIE
# 4  tm1000022  Boonie Bears: The Wild Life  MOVIE
#
#                                          description  release_year  \
# 0  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 1  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 2  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 3  Bear brothers Briar and Bramble set off on an ...          2021
# 4  Bear brothers Briar and Bramble set off on an ...          2021
#
#   age_certification  runtime     genres production_countries  seasons  \
# 0           Unknown       61    western                   US        0
# 1           Unknown       61     action                   US        0
# ...

# %%
# Checking for unique values production_countries
df_exploded.production_countries.unique()
# Out:
# array(['US', 'CN', nan, 'IN', 'GB', 'NO', 'CA', 'IT', 'FR', 'ES', 'DE',
#        'LI', 'RS', 'XX', 'BE', 'MC', 'SE', 'MX', 'AT', 'CO', 'IL', 'JP',
#        'KE', 'CZ', 'VN', 'AU', 'KR', 'IR', 'PL', 'PH', 'ZA', 'TH', 'BR',
#        'RO', 'HK', 'AR', 'GR', 'DK', 'NZ', 'IE', 'NG', 'RU', 'JM', 'CL',
#        'NL', 'FI', 'TW', 'YU', 'XC', 'HU', 'AN', 'SU', 'CH', 'VE', 'PT',
#        'UA', 'LU', 'TR', 'IS', 'AE', 'AF', 'ID', 'MA', 'SK', 'EG', 'PR',
#        'SO', 'MY', 'SG', 'KZ', 'LT', 'United States of America', 'BO',
#        'TN', 'QA', 'BG', 'GQ', 'FJ', 'SZ', 'PK', 'MT', 'LY', 'TT', 'MN',
#        'LV', 'AQ', 'BM', 'UG', 'XK', 'HR', 'LB', 'TC', 'DO', 'GE', 'SV',
#        'SI', 'BA', 'BD', 'PS', 'KH', 'PE', 'CU', 'PA', 'AL', 'CY', 'CR',
#        'EC', 'PF', 'JO', 'EE', 'ET', 'UY', 'SY', 'PY', 'AM', 'CI', 'CM',
#        'IO'], dtype=object)

# %%
# Executing the mapping for production_countries

country_mapping = {
    'US': 'United States',
    'CN': 'China',
    'IN': 'India',
    'GB': 'United Kingdom',
    'NO': 'Norway',
    'CA': 'Canada',
    'IT': 'Italy',
    'FR': 'France',
    'ES': 'Spain',
    'DE': 'Germany',
    'LI': 'Liechtenstein',
    'RS': 'Serbia',
    'XX': 'Unknown',
    'BE': 'Belgium',
    'MC': 'Monaco',
    'SE': 'Sweden',
    'MX': 'Mexico',
    'AT': 'Austria',
    'CO': 'Colombia',
    'IL': 'Israel',
    'JP': 'Japan',
    'KE': 'Kenya',
    'CZ': 'Czech Republic',
    'VN': 'Vietnam',
    'AU': 'Australia',
    'KR': 'South Korea',
    'IR': 'Iran',
    'PL': 'Poland',
    'PH': 'Philippines',
    'ZA': 'South Africa',
    'TH': 'Thailand',
    'BR': 'Brazil',
    'RO': 'Romania',
    'HK': 'Hong Kong',
    'AR': 'Argentina',
    'GR': 'Greece',
    'DK': 'Denmark',
    'NZ': 'New Zealand',
    'IE': 'Ireland',
    'NG': 'Nigeria',
    'RU': 'Russia',
    'JM': 'Jamaica',
    'CL': 'Chile',
    'NL': 'Netherlands',
    'FI': 'Finland',
    'TW': 'Taiwan',
    'YU': 'Yugoslavia',
    'XC': 'Czechoslovakia',
    'HU': 'Hungary',
    'AN': 'Netherlands Antilles',
    'SU': 'Soviet Union',
    'CH': 'Switzerland',
    'VE': 'Venezuela',
    'PT': 'Portugal',
    'UA': 'Ukraine',
    'LU': 'Luxembourg',
    'TR': 'Turkey',
    'IS': 'Iceland',
    'AE': 'United Arab Emirates',
    'AF': 'Afghanistan',
    'ID': 'Indonesia',
    'MA': 'Morocco',
    'SK': 'Slovakia',
    'EG': 'Egypt',
    'PR': 'Puerto Rico',
    'SO': 'Somalia',
    'MY': 'Malaysia',
    'SG': 'Singapore',
    'KZ': 'Kazakhstan',
    'LT': 'Lithuania',
    'United States of America': 'United States',
    'BO': 'Bolivia',
    'TN': 'Tunisia',
    'QA': 'Qatar',
    'BG': 'Bulgaria',
    'GQ': 'Equatorial Guinea',
    'FJ': 'Fiji',
    'SZ': 'Eswatini',
    'PK': 'Pakistan',
    'MT': 'Malta',
    'LY': 'Libya',
    'TT': 'Trinidad and Tobago',
    'MN': 'Mongolia',
    'LV': 'Latvia',
    'AQ': 'Antarctica',
    'BM': 'Bermuda',
    'UG': 'Uganda',
    'XK': 'Kosovo',
    'HR': 'Croatia',
    'LB': 'Lebanon',
    'TC': 'Turks and Caicos Islands',
    'DO': 'Dominican Republic',
    'GE': 'Georgia',
    'SV': 'El Salvador',
    'SI': 'Slovenia',
    'BA': 'Bosnia and Herzegovina',
    'BD': 'Bangladesh',
    'PS': 'Palestine',
    'KH': 'Cambodia',
    'PE': 'Peru',
    'CU': 'Cuba',
    'PA': 'Panama',
    'AL': 'Albania',
    'CY': 'Cyprus',
    'CR': 'Costa Rica',
    'EC': 'Ecuador',
    'PF': 'French Polynesia',
    'JO': 'Jordan',
    'EE': 'Estonia',
    'ET': 'Ethiopia',
    'UY': 'Uruguay',
    'SY': 'Syria',
    'PY': 'Paraguay',
    'AM': 'Armenia',
    'CI': 'Ivory Coast',
    'CM': 'Cameroon',
    'IO': 'British Indian Ocean Territory',
    None: 'Unknown'
}

df_exploded.production_countries = df_exploded.production_countries.replace(country_mapping)

# %%
# Checking for sccessful mapping
df_exploded.head()
# Out:
#           id                        title   type  \
# 0   tm100001              The Lucky Texan  MOVIE
# 1   tm100001              The Lucky Texan  MOVIE
# 2   tm100001              The Lucky Texan  MOVIE
# 3  tm1000022  Boonie Bears: The Wild Life  MOVIE
# 4  tm1000022  Boonie Bears: The Wild Life  MOVIE
#
#                                          description  release_year  \
# 0  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 1  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 2  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 3  Bear brothers Briar and Bramble set off on an ...          2021
# 4  Bear brothers Briar and Bramble set off on an ...          2021
#
#   age_certification  runtime     genres production_countries  seasons  \
# 0           Unknown       61    western        United States        0
# 1           Unknown       61     action        United States        0
# ...

# %%
df_exploded.genres.unique()
# Out:
# array(['western', 'action', 'romance', 'scifi', 'animation', 'comedy',
#        'drama', 'thriller', 'horror', 'european', 'crime',
#        'documentation', 'family', 'music', 'war', 'fantasy', 'sport', nan,
#        'history', 'reality'], dtype=object)

# %%
# Fixing null values in genres
df_exploded['genres'].fillna("Unknown", inplace=True)

# %%
# Finalizing the DataFrame
df_exploded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25819 entries, 0 to 25818
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    25819 non-null  object
#  1   title                 25819 non-null  object
#  2   type                  25819 non-null  object
#  3   description           25819 non-null  object
#  4   release_year          25819 non-null  int64
#  5   age_certification     25819 non-null  object
#  6   runtime               25819 non-null  int64
#  7   genres                25819 non-null  object
#  8   production_countries  25819 non-null  object
#  9   seasons               25819 non-null  int64
#  10  imdb_score            25819 non-null  float64
#  11  imdb_votes            25819 non-null  float64
#  12  tmdb_popularity       25819 non-null  float64
#  13  tmdb_score            25819 non-null  float64
#  14  person_id             25819 non-null  object
# ...

# %%
# Final Check for missing values
df_exploded.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %% [markdown]
# ### Outlier Detection

# %%
# Identify numerical columns
numerical_columns = ['imdb_score']

# Find outliers using IQR method and display bounds
outlier_bounds = {}
for column in numerical_columns:
    Q1 = df_exploded[column].quantile(0.25)
    Q3 = df_exploded[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_bounds[column] = (lower_bound, upper_bound)

# Display lower and upper bounds for each column
for column, bounds in outlier_bounds.items():
    print(f"{column} - Lower Bound: {bounds[0]}, Upper Bound: {bounds[1]}")
# Out:
# imdb_score - Lower Bound: 2.899999999999999, Upper Bound: 9.3

# %%
# Identify numerical columns
numerical_columns = ['tmdb_score']

# Find outliers using IQR method and display bounds
outlier_bounds = {}
for column in numerical_columns:
    Q1 = df_exploded[column].quantile(0.25)
    Q3 = df_exploded[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outlier_bounds[column] = (lower_bound, upper_bound)

# Display lower and upper bounds for each column
for column, bounds in outlier_bounds.items():
    print(f"{column} - Lower Bound: {bounds[0]}, Upper Bound: {bounds[1]}")
# Out:
# tmdb_score - Lower Bound: 3.300000000000001, Upper Bound: 8.899999999999999

# %% [markdown]
# Outliers should not be removed in this case because they represent extreme values that could provide valuable insights into the dataset. For example, in the context of movies and TV shows, outliers might indicate exceptionally popular or highly rated content, which could be critical for understanding audience preferences or identifying standout titles. Removing these data points could lead to a loss of important information and skew the analysis.
#
# Additionally, the threshold of 10 is significant because it ensures that we retain enough data points for meaningful analysis. If we were to remove outliers below or above this threshold, we might inadvertently exclude rare but important cases, such as niche genres or unique production countries, which could provide valuable insights into the diversity and reach of the content library.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Based on the dataset and the changes I've been made, here is what we know about the dataset:
#
# 1. **Dataset Overview**:
#     - The dataset contains information about Amazon Prime TV shows and movies, including details such as title, type (movie or show), description, release year, runtime, genres, production countries, IMDb and TMDb ratings, and more.
#
# 2. **Data Cleaning**:
#     - Missing values in columns like `description`, `age_certification`, `seasons`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, and `tmdb_score` were handled appropriately.
#     - Duplicate rows were identified and removed to ensure data consistency.
#     - The `imdb_id` column was dropped as it was deemed unnecessary for analysis.
#
# 3. **Data Transformation**:
#     - The `genres` and `production_countries` columns were exploded to allow for more granular analysis.
#     - A mapping was applied to standardize country codes in the `production_countries` column.
#
# 4. **Key Variables**:
#     - The dataset includes both categorical and numerical variables, such as `type`, `genres`, `release_year`, `runtime`, `imdb_score`, and `tmdb_popularity`, which are useful for exploratory data analysis.
#
# 5. **Insights from Data**:
#     - The dataset provides a mix of movies and TV shows with diverse genres and production countries.
#     - Popularity and ratings metrics (IMDb and TMDb) offer insights into audience preferences.
#     - The cleaned and transformed dataset is now ready for univariate, bivariate, and multivariate analysis to uncover trends and patterns.
#
# This understanding sets the foundation for further exploratory data analysis and visualization.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# #### **Manipulations Done:**
# 1. **Data Cleaning:**
#     - Removed duplicate rows based on the `id` column to ensure data consistency.
#     - Handled missing values in various columns:
#       - Filled missing values in `description` with "No Description".
#       - Replaced missing values in `age_certification` with the mode or "Unknown".
#       - Filled missing values in `seasons` with 0 and converted the column to integer type.
#       - Dropped the `imdb_id` column as it was deemed unnecessary for analysis.
#       - Replaced missing values in numerical columns (`imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score`) with their respective medians.
#       - Filled missing values in `person_id`, `name`, `character`, and `role` with "Unknown".
#
# 2. **Data Transformation:**
#     - Exploded the `genres` and `production_countries` columns to allow for more granular analysis.
#     - Applied a mapping to standardize country codes in the `production_countries` column.
#     - Fixed null values in the `genres` column by replacing them with "Unknown".
#
# 3. **Data Aggregation:**
#     - Created a new dataframe (`df_exploded`) by exploding the `genres` and `production_countries` columns for detailed analysis.
#     - Mapped country codes to their full names using a predefined dictionary.
#
# 4. **Data Validation:**
#     - Verified the removal of duplicate rows and ensured no duplicates remained.
#     - Checked for unique values in key columns to validate the transformations.
#
# 5. **Outlier Detection:**
#     - Identified outliers in numerical columns like `tmdb_popularity` and `imdb_score` using the IQR method.
#     - Retained outliers for analysis as they provide valuable insights into extreme cases.
#
# These manipulations set the foundation for further exploratory data analysis and visualization to uncover deeper trends and patterns.

# %% [markdown]
# ## ***3. Understanding Your Variables***

# %%
# Dataset Columns
df_exploded.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score',
#        'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
# Dataset Describe
df_exploded.describe()
# Out:
#        release_year       runtime       seasons    imdb_score    imdb_votes  \
# count  25819.000000  25819.000000  25819.000000  25819.000000  2.581900e+04
# mean    2000.428754     88.268910      0.432821      6.011747  1.246577e+04
# std       25.610293     33.395277      1.951025      1.265653  5.413639e+04
# min     1912.000000      1.000000      0.000000      1.100000  5.000000e+00
# 25%     1994.000000     71.000000      0.000000      5.300000  2.030000e+02
# 50%     2012.000000     90.000000      0.000000      6.100000  7.050000e+02
# 75%     2018.000000    105.000000      0.000000      6.900000  4.235000e+03
# max     2022.000000    549.000000     51.000000      9.900000  1.133692e+06
#
#        tmdb_popularity    tmdb_score
# count     25819.000000  25819.000000
# mean          9.509440      6.040606
# std          36.489698      1.318099
# min           0.000011      0.800000
# 25%           1.641000      5.400000
# 50%           3.366000      6.000000
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for x in df_exploded.columns:
    print(f"{x} - {df_exploded[x].nunique()}")
# Out:
# id - 9868
# title - 9737
# type - 2
# description - 9735
# release_year - 110
# age_certification - 12
# runtime - 207
# genres - 20
# production_countries - 116
# seasons - 33
# imdb_score - 86
# imdb_votes - 3650
# tmdb_popularity - 5325
# tmdb_score - 89
# person_id - 6640
# name - 6632
# character - 6178
# role - 3

# %% [markdown]
# ### Variables Description

# %% [markdown]
# #### Dataset: `df`(Outer Join has been performed between titles and credits)
# 1. **id**: Unique identifier for each title (movie or show).
#     - **Data Type**: `object`
#     - **Unique Values**: 9868
#     - **Missing Values**: 0
#
# 2. **title**: Title of the movie or show.
#     - **Data Type**: `object`
#     - **Unique Values**: 9737
#     - **Missing Values**: 0
#
# 3. **type**: Type of content (e.g., MOVIE, SHOW).
#     - **Data Type**: `object`
#     - **Unique Values**: 2
#     - **Missing Values**: 0
#
# 4. **description**: Brief description of the content.
#     - **Data Type**: `object`
#     - **Unique Values**: 9735
#     - **Missing Values**: 0 (after handling)
#
# 5. **release_year**: Year the content was released.
#     - **Data Type**: `int64`
#     - **Unique Values**: 110
#     - **Missing Values**: 0
#
# 6. **age_certification**: Age certification for the content.
#     - **Data Type**: `object`
#     - **Unique Values**: 11
#     - **Missing Values**: 0 (after handling)
#
# 7. **runtime**: Duration of the content in minutes.
#     - **Data Type**: `int64`
#     - **Unique Values**: 207
#     - **Missing Values**: 0
#
# 8. **genres**: List of genres associated with the content.
#     - **Data Type**: `object`
#     - **Unique Values**: 2028
#     - **Missing Values**: 0
#
# 9. **production_countries**: List of countries where the content was produced.
#     - **Data Type**: `object`
#     - **Unique Values**: 497
#     - **Missing Values**: 0
#
# 10. **seasons**: Number of seasons (for shows).
#      - **Data Type**: `int64`
#      - **Unique Values**: 33
#      - **Missing Values**: 0 (after handling)
#
# 11. **imdb_score**: IMDb rating of the content.
#      - **Data Type**: `float64`
#      - **Unique Values**: 86
#      - **Missing Values**: 0 (after handling)
#
# 12. **imdb_votes**: Number of votes on IMDb.
#      - **Data Type**: `float64`
#      - **Unique Values**: 3650
#      - **Missing Values**: 0 (after handling)
#
# 13. **tmdb_popularity**: Popularity score on TMDb.
#      - **Data Type**: `float64`
#      - **Unique Values**: 5325
#      - **Missing Values**: 0 (after handling)
#
# 14. **tmdb_score**: TMDb rating of the content.
#      - **Data Type**: `float64`
#      - **Unique Values**: 89
#      - **Missing Values**: 0 (after handling)
#
# 15. **person_id**: Unique identifier for a person (actor, director, etc.).
#      - **Data Type**: `object`
#      - **Unique Values**: 6640
#      - **Missing Values**: 0 (after handling)
#
# 16. **name**: Name of the person (actor, director, etc.).
#      - **Data Type**: `object`
#      - **Unique Values**: 6632
#      - **Missing Values**: 0 (after handling)
#
# 17. **character**: Character played by the actor (if applicable).
#      - **Data Type**: `object`
#      - **Unique Values**: 6178
#      - **Missing Values**: 0 (after handling)
#
# 18. **role**: Role of the person (e.g., ACTOR, DIRECTOR).
#      - **Data Type**: `object`
#      - **Unique Values**: 3
#      - **Missing Values**: 0

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# 1. Distribution of content types
plt.figure(figsize=(12, 6))
ax = df_exploded['type'].value_counts().plot(kind='bar', color='skyblue', title='Content Type Distribution')
plt.xlabel('Type')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax.containers:
    ax.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.xticks(rotation=360)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes categorical data, such as the distribution of content types (e.g., movies and shows). It provides a clear comparison of the frequency of each category, making it easy to identify trends and patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the proportion of movies and shows in the dataset. For example, if movies significantly outnumber shows, it indicates that Amazon Prime Video's content library is more focused on movies. Conversely, a balanced distribution suggests equal emphasis on both types of content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. If movies dominate the platform, it may consider increasing the production or acquisition of TV shows to attract viewers who prefer episodic content. Conversely, if shows are more prevalent, the platform could focus on acquiring blockbuster movies to balance its offerings. Understanding content type distribution enables data-driven decisions to enhance audience engagement and subscription growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# 2. Most common genres
df_exploded['genres'] = df_exploded['genres'].astype(str).str.strip('[]').str.replace("'", "").str.split(', ')

# Flatten the list of genres and count the occurrences
genre_counts = pd.Series([genre for sublist in df_exploded['genres'] for genre in sublist]).value_counts().head(10)

# Plot the top 10 genres
plt.figure(figsize=(20, 6))
ax1 = genre_counts.plot(kind='bar', color='orange', title='Top 10 Genres')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax1.containers:
    ax1.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes the frequency of categorical data, such as genres. It provides a clear comparison of the most common genres, making it easy to identify trends and patterns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 10 most common genres in the dataset. For example, genres like drama, comedy, and thriller are among the most prevalent. This indicates audience preferences and the platform's focus on these genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By understanding the most popular genres, the platform can focus on acquiring or producing more content in these genres to cater to audience preferences. Additionally, identifying less common genres may highlight opportunities to diversify the content library and attract niche audiences.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# 3. Runtime distribution
plt.figure(figsize=(20, 6))
sns.histplot(df_exploded['runtime'], kde=True, color='green', bins=30)
plt.title('Runtime Distribution')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram was chosen because it effectively visualizes the distribution of numerical data, such as runtime. It provides a clear view of how the runtime values are spread across the dataset, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the distribution of runtime for movies and TV shows. For example, it may show that most content has a runtime between 90-120 minutes, with fewer entries for shorter or longer durations. This insight helps understand the typical length of content on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. If the majority of content falls within a specific runtime range, the platform can focus on producing or acquiring content that aligns with audience preferences. Additionally, identifying gaps in runtime distribution may highlight opportunities to cater to niche audiences who prefer shorter or longer content. This data-driven approach can enhance user satisfaction and engagement.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# 4. Frequency of content release by year
plt.figure(figsize=(20, 6))
df_exploded['release_year'].value_counts().sort_index().plot(kind='line', color='purple', marker='o', title='Content Release Frequency by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line chart was chosen because it effectively visualizes trends over time, such as the frequency of content releases by year. It provides a clear view of how the number of releases has evolved, highlighting peaks and troughs in production activity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the years with the highest and lowest content releases. For example, there may be a steady increase in releases over time, with notable peaks in certain years. This could indicate periods of increased production or strategic focus on content acquisition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video identify trends in content production and acquisition. Understanding peak years can guide future strategies, such as replicating successful patterns or addressing gaps in production. Additionally, analyzing dips in releases may highlight opportunities to increase content output during slower periods, ensuring consistent audience engagement and subscription growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# 5. Most common age certifications
# Filter out the "Unknown" category
filtered_data = df_exploded[df_exploded['age_certification'] != "Unknown"]

# Plot the chart
plt.figure(figsize=(20, 6))
ax2 = filtered_data['age_certification'].value_counts().plot(kind='bar', color='red', title='Age Certification Distribution')
plt.xlabel('Age Certification')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax2.containers:
    ax2.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes categorical data, such as the distribution of age certifications. It provides a clear comparison of the frequency of each certification, making it easy to identify trends and patterns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the most common age certifications in the dataset. For example, certifications like "TV-MA" and "PG-13" may dominate, indicating that the platform primarily targets mature audiences or families. Conversely, a significant presence of "TV-Y" or "G" certifications suggests content aimed at younger viewers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By understanding the distribution of age certifications, the platform can focus on acquiring or producing content that aligns with its target audience. For example, if mature content dominates, the platform may consider diversifying its offerings to attract younger viewers or families. This data-driven approach can enhance audience engagement, broaden the subscriber base, and drive subscription growth.

# %% [markdown]
# ### **Bivariate Analysis**

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# 6. Relationship between IMDb and TMDb scores
plt.figure(figsize=(12, 6))
sns.scatterplot(x='imdb_score', y='tmdb_score', data=df_exploded, alpha=0.6)
plt.title('IMDb vs TMDb Scores')
plt.xlabel('IMDb Score')
plt.ylabel('TMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen because it effectively visualizes the relationship between two numerical variables, IMDb scores and TMDb scores. It provides a clear view of how these scores correlate, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the correlation between IMDb and TMDb scores. For example, a strong positive correlation indicates that content rated highly on IMDb tends to receive high ratings on TMDb as well. Conversely, a weak correlation suggests differences in audience preferences or rating criteria between the two platforms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video understand how its content is perceived across different platforms. If a strong correlation exists, the platform can confidently use one score as a proxy for the other in marketing or analysis. If discrepancies are identified, it may explore the reasons behind them to better cater to diverse audience preferences, ultimately enhancing user satisfaction and engagement.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# 7. Runtime variation across genres
plt.figure(figsize=(12, 6))
sns.boxplot(x='genres', y='runtime', data=df_exploded.explode('genres'))
plt.xticks(rotation=90)
plt.title('Runtime Variation Across Genres')
plt.xlabel('Genres')
plt.ylabel('Runtime (minutes)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The boxplot was chosen because it effectively visualizes the distribution and variation of runtime across different genres. It highlights the median, interquartile range, and potential outliers, providing a clear understanding of how runtime differs among genres.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the runtime distribution for each genre. For example, genres like "documentation" and "drama" may have longer runtimes, while genres like "animation" and "family" tend to have shorter runtimes. This insight helps identify the typical duration of content based on genre.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. Understanding runtime preferences by genre allows the platform to tailor its offerings to audience expectations. For instance, producing shorter content for genres like "animation" may cater to younger viewers, while longer content for "documentation" may appeal to niche audiences. This data-driven approach can enhance user satisfaction and engagement, driving subscription growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# 8. Relationship between release year and IMDb scores
plt.figure(figsize=(20, 6))
sns.lineplot(x='release_year', y='imdb_score', data=df_exploded, marker='o', color='blue')
plt.title('Release Year vs IMDb Scores')
plt.xlabel('Release Year')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line chart was chosen because it effectively visualizes trends over time, such as the relationship between release year and IMDb scores. It provides a clear view of how IMDb scores have evolved across different years, highlighting patterns, peaks, and troughs in audience ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals how IMDb scores vary by release year. For example, older movies may have higher scores due to their classic status, while newer movies might show a mix of high and low scores depending on audience reception. This insight helps identify trends in audience preferences and the quality of content over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content acquisition strategy. By understanding which release years tend to have higher IMDb scores, the platform can focus on acquiring or promoting content from those years to attract viewers. Additionally, identifying years with lower scores may highlight opportunities to improve content offerings or target niche audiences. This data-driven approach can enhance user satisfaction and engagement, driving subscription growth.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# 9. Correlation between IMDb votes and IMDb scores
plt.figure(figsize=(12, 6))
sns.scatterplot(x='imdb_votes', y='imdb_score', data=df_exploded, alpha=0.6)
plt.title('IMDb Votes vs IMDb Scores')
plt.xlabel('IMDb Votes')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen because it effectively visualizes the relationship between two numerical variables, IMDb votes and IMDb scores. It provides a clear view of how these variables correlate, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the correlation between IMDb votes and IMDb scores. For example, content with higher IMDb votes often tends to have higher scores, indicating that popular content is generally well-received. Conversely, content with fewer votes may show a wider range of scores, suggesting variability in audience reception.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By understanding the relationship between votes and scores, the platform can identify highly-rated content with significant audience engagement to promote or acquire similar content. Additionally, analyzing content with fewer votes but high scores may highlight hidden gems worth promoting to increase visibility and engagement. This data-driven approach can enhance user satisfaction and drive subscription growth.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# 10. Scatter plot of runtime vs seasons
plt.figure(figsize=(12, 6))
sns.scatterplot(x='runtime',y='seasons',data=df_exploded,color='r')
plt.xlabel('Runtime (of one episode)')
plt.ylabel('Seasons')
plt.title('Scatter Plot: Runtime vs Seasons')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen because it effectively visualizes the relationship between two numerical variables, runtime and seasons. It provides a clear view of how these variables correlate, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the distribution of runtime across different numbers of seasons. For example, shows with fewer seasons may have shorter runtimes, while shows with more seasons might exhibit a wider range of runtimes. This insight helps identify trends in episodic content duration.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By understanding the relationship between runtime and seasons, the platform can tailor its offerings to audience preferences. For instance, producing shorter episodes for shows with many seasons may cater to binge-watchers, while longer episodes for limited-season shows may appeal to viewers seeking in-depth storytelling. This data-driven approach can enhance user satisfaction and engagement, driving subscription growth.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# 11. Distribution of Top 10 Production Countries for Shows
# Filter the dataset for shows
shows_data = df_exploded[df_exploded['type'] == 'SHOW']

# Filter out the "Unknown" category
filtered_shows_data = shows_data[shows_data['production_countries'] != "Unknown"]

# Count the occurrences of production countries
filtered_country_counts = filtered_shows_data['production_countries'].value_counts().head(10)

# Plot the top 10 production countries for shows
plt.figure(figsize=(20, 6))
ax3 = filtered_country_counts.plot(kind='bar', color='teal', title='Top 10 Production Countries for Shows')
plt.xlabel('Production Countries')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax3.containers:
    ax3.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes categorical data, such as the distribution of production countries for shows. It provides a clear comparison of the frequency of shows produced in different countries, making it easy to identify trends and patterns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 10 production countries for shows. For example, countries like the United States, United Kingdom, and Canada may dominate the list, indicating their significant contribution to the production of TV shows. Conversely, countries with fewer entries highlight opportunities for growth in content production.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content acquisition strategy. By understanding which countries produce the most shows, the platform can focus on acquiring or promoting content from these regions to cater to audience preferences. Additionally, identifying countries with fewer productions may highlight opportunities to invest in or collaborate with emerging markets, broadening the content library and attracting diverse audiences. This data-driven approach can enhance user satisfaction and drive subscription growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# 12. Distribution of Top 10 Production Countries for Movies
# Filter the dataset for movies
movies_data = df_exploded[df_exploded['type'] == 'MOVIE']

# Filter the dataset for movies and exclude "Unknown" production countries
movies_data = df_exploded[(df_exploded['type'] == 'MOVIE') & (df_exploded['production_countries'] != "Unknown")]

# Count the occurrences of production countries
movie_country_counts = movies_data['production_countries'].value_counts().head(10)

# Plot the top 10 production countries for movies
plt.figure(figsize=(20, 6))
ax4 = movie_country_counts.plot(kind='bar', color='blue', title='Top 10 Production Countries for Movies')
plt.xlabel('Production Countries')
plt.ylabel('Count')

# Add labels on top of each bar
for patch in ax4.patches:
    ax4.annotate(f'{int(patch.get_height())}', 
                 (patch.get_x() + patch.get_width() / 2, patch.get_height()), 
                 ha='center', va='bottom', fontsize=9)
    


plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes categorical data, such as the distribution of production countries for movies. It provides a clear comparison of the frequency of movies produced in different countries, making it easy to identify trends and patterns in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 10 production countries for movies. For example, countries like the United States, India, and the United Kingdom dominate the list, indicating their significant contribution to movie production. Conversely, countries with fewer entries highlight opportunities for growth in content production.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content acquisition strategy. By understanding which countries produce the most movies, the platform can focus on acquiring or promoting content from these regions to cater to audience preferences. Additionally, identifying countries with fewer productions may highlight opportunities to invest in or collaborate with emerging markets, broadening the content library and attracting diverse audiences. This data-driven approach can enhance user satisfaction and drive subscription growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# 13. Top 5 Highest-Rated Shows Based on IMDb Score
# Filter the top 5 highest-rated shows based on IMDb score
highest_rated_shows = filtered_shows_data.sort_values(by='imdb_score', ascending=False).head(10)

# Filter the top 5 highest-rated shows based on IMDb score
top_5_highest_rated_shows = highest_rated_shows.nlargest(10, 'imdb_score')

# Plot the chart
plt.figure(figsize=(12, 6))
ax7 = sns.barplot(x='title', y='imdb_score', data=top_5_highest_rated_shows, palette='viridis')
plt.title('Top 5 Highest-Rated Shows Based on IMDb Score')
plt.xlabel('Show Title')
plt.ylabel('IMDb Score')
plt.xticks(rotation=45, ha='right')

# Add labels on top of each bar
for container in ax7.containers:
    ax7.bar_label(container, fmt='%.1f', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes the IMDb scores of the top 5 highest-rated shows. It provides a clear comparison of the ratings, making it easy to identify the standout shows in terms of audience reception.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 5 highest-rated shows based on IMDb scores. For example, shows like "Couple of Mirrors" and "The Chosen" have exceptionally high ratings, indicating strong audience approval. This insight highlights the shows that are most appreciated by viewers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By identifying the highest-rated shows, the platform can focus on promoting similar content or leveraging these shows in marketing campaigns to attract more viewers. Additionally, understanding audience preferences for highly-rated shows can guide future content acquisition and production decisions, driving subscription growth and enhancing user satisfaction.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
# 14. Top 5 Most Popular Shows Based on TMDb Popularity
# Sort the shows_data dataframe by tmdb_popularity in descending order
top_5_popular_shows = shows_data.sort_values(by='tmdb_popularity', ascending=False).head(15)

# Display the top 5 most popular shows
print(top_5_popular_shows[['title', 'tmdb_popularity']])

# Visualize the top 5 most popular shows
plt.figure(figsize=(12, 6))
ax8 = sns.barplot(x='tmdb_popularity', y='title', data=top_5_popular_shows, palette='coolwarm')
plt.title('Top 5 Most Popular Shows Based on TMDb Popularity')
plt.xlabel('TMDb Popularity')
plt.ylabel('Show Title')
plt.tight_layout()

# Add labels on top of each bar
for container in ax8.containers:
    ax8.bar_label(container, fmt='%.1f', fontsize=9)



plt.show()
# Out:
#                   title  tmdb_popularity
# 24369            Harina          951.863
# 23397             Suits          356.533
# 23398             Suits          356.533
# 25419  Better Call Saul          352.657
# 25418  Better Call Saul          352.657
# 25420  Better Call Saul          352.657
# 23446           Vikings          344.245
# 23451           Vikings          344.245
# 23449           Vikings          344.245
# 23447           Vikings          344.245
# 23450           Vikings          344.245
# 23448           Vikings          344.245
# 24255           Reacher          323.037
# 24254           Reacher          323.037
# 24253           Reacher          323.037

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen because it effectively visualizes the TMDb popularity scores of the top 5 most popular shows. It provides a clear comparison of the popularity of these shows, making it easy to identify the standout titles in terms of audience engagement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the top 5 most popular shows based on TMDb popularity scores. For example, shows like "Harina" and "Better Call Saul" have exceptionally high popularity, indicating strong audience interest. This insight highlights the shows that are most engaging and widely appreciated by viewers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By identifying the most popular shows, the platform can focus on promoting similar content or leveraging these shows in marketing campaigns to attract more viewers. Additionally, understanding audience preferences for highly popular shows can guide future content acquisition and production decisions, driving subscription growth and enhancing user satisfaction.

# %% [markdown]
# ### **Multivariate Analysis**

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code
# 15. Interaction of IMDb scores, TMDb scores, and TMDb popularity across genres
# Filter out rows where genres contain 'Unknown'
filtered_df = df_exploded[df_exploded['genres'] != 'Unknown']


# Explode the 'genres' column to ensure each genre is in a separate row
filtered_df_exploded = filtered_df.explode('genres')

# Filter out rows where the genre is 'Unknown'
filtered_df_exploded = filtered_df_exploded[filtered_df_exploded['genres'] != 'Unknown']

# Plot the filtered data
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='imdb_score', 
    y='tmdb_score', 
    size='tmdb_popularity', 
    hue='genres', 
    data=filtered_df_exploded, 
    alpha=0.6
)
plt.title('IMDb vs TMDb Scores by Genres (Excluding Unknown)')
plt.xlabel('IMDb Score')
plt.ylabel('TMDb Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen because it effectively visualizes the interaction between three variables: IMDb scores, TMDb scores, and TMDb popularity, categorized by genres. It provides a clear view of how these variables correlate and vary across genres, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals how IMDb scores and TMDb scores correlate across genres, with TMDb popularity providing additional context. For example, genres with higher IMDb and TMDb scores tend to have higher popularity, indicating audience preference. Conversely, genres with lower scores may show variability in popularity, suggesting niche appeal or mixed reception.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content strategy. By understanding the interaction between scores and popularity across genres, the platform can focus on acquiring or producing content in genres with high scores and popularity to cater to audience preferences. Additionally, identifying genres with lower scores but high popularity may highlight opportunities to invest in improving content quality while maintaining audience engagement. This data-driven approach can enhance user satisfaction and drive subscription growth.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code
# 16. Relationship between runtime, IMDb scores, and release year
plt.figure(figsize=(10, 6))
sns.scatterplot(x='runtime', y='imdb_score', hue='release_year', data=df, alpha=0.6)
plt.title('Runtime vs IMDb Scores by Release Year')
plt.xlabel('Runtime (minutes)')
plt.ylabel('IMDb Score')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot was chosen because it effectively visualizes the relationship between three numerical variables: runtime, IMDb scores, and release year. By using color to represent release year, the chart provides a clear view of how runtime and IMDb scores vary across different years, highlighting patterns, clusters, and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals how runtime and IMDb scores correlate across different release years. For example, movies with longer runtimes may tend to have higher IMDb scores, indicating audience preference for detailed storytelling. Additionally, older movies may show higher scores due to their classic status, while newer movies exhibit a mix of high and low scores depending on audience reception.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, these insights can help Amazon Prime Video optimize its content acquisition and production strategy. By understanding the relationship between runtime, IMDb scores, and release year, the platform can focus on acquiring or producing content that aligns with audience preferences. For instance, investing in longer, high-quality movies from specific years may attract viewers seeking in-depth storytelling. This data-driven approach can enhance user satisfaction and engagement, driving subscription growth.

# %% [markdown]
# #### Chart - 17 - Correlation Heatmap

# %%
# 17. Correlation Heatmap visualization code
plt.figure(figsize=(12, 8))

# Select only numeric columns
numeric_columns = df_exploded.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Plot the heatmap
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen because it effectively visualizes the relationships between numerical variables in the dataset. It provides a clear overview of how variables are correlated, highlighting positive, negative, or neutral relationships. This helps identify patterns and dependencies between features, which can be useful for further analysis or modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap reveals the strength and direction of correlations between numerical variables. For example, a strong positive correlation between `imdb_votes` and `imdb_score` indicates that movies with more votes tend to have higher scores. Conversely, weak or negative correlations highlight variables that are less related or inversely related. These insights can guide feature selection and help understand the dynamics of the dataset.

# %% [markdown]
# #### Chart - 18 - Pair Plot

# %%
# Pair Plot visualization code
# Select numeric columns and the 'type' column
numeric_columns = df_exploded.select_dtypes(include='number')
type_column = df_exploded[['type']]

# Combine numeric columns with the 'type' column
data_for_pairplot = pd.concat([numeric_columns, type_column], axis=1)

# Generate the pair plot
sns.pairplot(data_for_pairplot, hue="type", palette="viridis")
plt.suptitle('Pair Plot of Numeric Columns by Type', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot was chosen because it effectively visualizes relationships between multiple numerical variables, categorized by the `type` column. It provides a comprehensive view of how these variables interact, highlighting correlations, distributions, and potential clusters.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals patterns and relationships between numerical variables such as `runtime`, `imdb_score`, `tmdb_popularity`, and others. For example, movies may show a wider range of runtimes compared to shows, while higher IMDb scores might correlate with higher TMDb popularity. Additionally, the distribution of variables across types helps identify trends specific to movies or shows.

# %% [markdown]
# ### Follow-up Questions

# %% [markdown]
# ### 1. **Content Diversity: What genres and categories dominate the platform?**

# %% [markdown]
# - The `genre_counts` variable shows that the most dominant genres are:
#       - **Drama**: 5466 entries
#       - **Comedy**: 3294 entries
#       - **Thriller**: 2460 entries
#       - **Action**: 2129 entries
#       - **Romance**: 1952 entries
#
#
# These genres dominate the platform, indicating a focus on diverse storytelling, ranging from serious narratives to light-hearted entertainment.

# %%
# 2. Most common genres
df_exploded['genres'] = df_exploded['genres'].astype(str).str.strip('[]').str.replace("'", "").str.split(', ')

# Flatten the list of genres and count the occurrences
genre_counts = pd.Series([genre for sublist in df_exploded['genres'] for genre in sublist]).value_counts().head(10)

# Plot the top 10 genres
plt.figure(figsize=(20, 6))
ax1 = genre_counts.plot(kind='bar', color='orange', title='Top 10 Genres')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax1.containers:
    ax1.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.show()

# %% [markdown]
# ### 2. **Regional Availability: How does content distribution vary across different regions?**

# %% [markdown]
# The `genre_country_counts` and `movie_country_counts` variables provide insights into regional distribution:
#
# - The **United States** leads in content production for both movies and shows, with 11,138 movies and 1,167 shows & significant contributions across genres.
#
# - Certain genres like **European** major contributors include **India**, **United Kingdom**, **Canada**, and **France**.and **Documentation** have higher contributions from countries like **France**, **Germany**, and **United Kingdom**.

# %%
# 11. Distribution of Top 10 Production Countries for Shows
# Filter the dataset for shows
shows_data = df_exploded[df_exploded['type'] == 'SHOW']

# Filter out the "Unknown" category
filtered_shows_data = shows_data[shows_data['production_countries'] != "Unknown"]

# Count the occurrences of production countries
filtered_country_counts = filtered_shows_data['production_countries'].value_counts().head(10)

# Plot the top 10 production countries for shows
plt.figure(figsize=(20, 6))
ax3 = filtered_country_counts.plot(kind='bar', color='teal', title='Top 10 Production Countries for Shows')
plt.xlabel('Production Countries')
plt.ylabel('Count')

# Add labels on top of each bar
for container in ax3.containers:
    ax3.bar_label(container, fmt='{:,.0f}', fontsize=9)

plt.show()

# %%
# 12. Distribution of Top 10 Production Countries for Movies
# Filter the dataset for movies
movies_data = df_exploded[df_exploded['type'] == 'MOVIE']

# Filter the dataset for movies and exclude "Unknown" production countries
movies_data = df_exploded[(df_exploded['type'] == 'MOVIE') & (df_exploded['production_countries'] != "Unknown")]

# Count the occurrences of production countries
movie_country_counts = movies_data['production_countries'].value_counts().head(10)

# Plot the top 10 production countries for movies
plt.figure(figsize=(20, 6))
ax4 = movie_country_counts.plot(kind='bar', color='blue', title='Top 10 Production Countries for Movies')
plt.xlabel('Production Countries')
plt.ylabel('Count')

# Add labels on top of each bar
for patch in ax4.patches:
    ax4.annotate(f'{int(patch.get_height())}', 
                 (patch.get_x() + patch.get_width() / 2, patch.get_height()), 
                 ha='center', va='bottom', fontsize=9)

plt.show()

# %% [markdown]
# ### 3. **Trends Over Time: How has Amazon Prime’s content library evolved?**

# %% [markdown]
# Amazon Prime's content library has shown significant growth and diversification over time. The platform has expanded its offerings across various genres, including drama, comedy, thriller, and action, as evidenced by the `genre_counts` data. Additionally, the inclusion of high-rated shows like "Couple of Mirrors" and "The Chosen" demonstrates a focus on quality content. The library also reflects a global perspective, with contributions from countries such as the United States, India, and the United Kingdom, highlighting its commitment to catering to diverse audiences.

# %%
# Group the dataset by release year and count the number of titles
titles_per_year = df_exploded.groupby('release_year')['genres'].count()

# Plot the evolution of content library over time
plt.figure(figsize=(20, 6))
titles_per_year.plot(kind='line', color='green', marker='o', title='Evolution of Amazon Prime Content Library')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. **IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?**

# %% [markdown]
# - **Highest-Rated Shows**:
#     - "Couple of Mirrors" (IMDb Score: 9.5) - A crime, drama, and romance show from China.
#     - "The Chosen" (IMDb Score: 9.4) - A historical drama from the United States.
#     - "Surgeons: At the Edge of Life" (IMDb Score: 9.2) - A documentary series from the United Kingdom.
#
# - **Most Popular Shows**:
#     - "Harina" (TMDb Popularity: 951.863) - A comedy show from Mexico.
#     - "Suits" (TMDb Popularity: 356.533) - A drama and comedy show from the United States.
#     - "Better Call Saul" (TMDb Popularity: 352.657) - A crime and drama show from the United States.
#
# These insights highlight Amazon Prime's ability to balance critically acclaimed content with audience favorites, ensuring a diverse and engaging library for its viewers.

# %%
# 13. Top 5 Highest-Rated Shows Based on IMDb Score
# Filter the top 5 highest-rated shows based on IMDb score
highest_rated_shows = filtered_shows_data.sort_values(by='imdb_score', ascending=False).head(10)

# Filter the top 5 highest-rated shows based on IMDb score
top_5_highest_rated_shows = highest_rated_shows.nlargest(10, 'imdb_score')

# Plot the chart
plt.figure(figsize=(12, 6))
ax7 = sns.barplot(x='title', y='imdb_score', data=top_5_highest_rated_shows, palette='viridis')
plt.title('Top 5 Highest-Rated Shows Based on IMDb Score')
plt.xlabel('Show Title')
plt.ylabel('IMDb Score')
plt.xticks(rotation=45, ha='right')

# Add labels on top of each bar
for container in ax7.containers:
    ax7.bar_label(container, fmt='%.1f', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# 14. Top 5 Most Popular Shows Based on TMDb Popularity
# Sort the shows_data dataframe by tmdb_popularity in descending order
top_5_popular_shows = shows_data.sort_values(by='tmdb_popularity', ascending=False).head(15)

# Display the top 5 most popular shows
print(top_5_popular_shows[['title', 'tmdb_popularity']])

# Visualize the top 5 most popular shows
plt.figure(figsize=(12, 6))
ax8 = sns.barplot(x='tmdb_popularity', y='title', data=top_5_popular_shows, palette='coolwarm')
plt.title('Top 5 Most Popular Shows Based on TMDb Popularity')
plt.xlabel('TMDb Popularity')
plt.ylabel('Show Title')
plt.tight_layout()

# Add labels on top of each bar
for container in ax8.containers:
    ax8.bar_label(container, fmt='%.1f', fontsize=9)

plt.show()
# Out:
#                   title  tmdb_popularity
# 24369            Harina          951.863
# 23397             Suits          356.533
# 23398             Suits          356.533
# 25419  Better Call Saul          352.657
# 25418  Better Call Saul          352.657
# 25420  Better Call Saul          352.657
# 23446           Vikings          344.245
# 23451           Vikings          344.245
# 23449           Vikings          344.245
# 23447           Vikings          344.245
# 23450           Vikings          344.245
# 23448           Vikings          344.245
# 24255           Reacher          323.037
# 24254           Reacher          323.037
# 24253           Reacher          323.037

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective, the client should focus on leveraging the insights gained from the analysis to optimize content strategy and audience engagement. Here are specific recommendations:
#
# 1. **Content Diversification**:
#     - Invest in genres with high IMDb scores and popularity, such as drama, thriller, and comedy, to cater to audience preferences.
#     - Explore opportunities in underrepresented genres like documentation and European content to attract niche audiences.
#
# 2. **Targeted Content Acquisition**:
#     - Focus on acquiring content from top production countries like the United States, India, and the United Kingdom, which dominate movie and show production.
#     - Collaborate with emerging markets to expand the content library and attract diverse audiences.
#
# 3. **Audience Segmentation**:
#     - Use age certification insights to tailor content offerings for different demographics, such as mature audiences (TV-MA) or families (TV-Y7).
#     - Analyze runtime preferences by genre to produce content that aligns with audience expectations, e.g., shorter episodes for animation and longer runtimes for drama.
#
# 4. **Quality Over Quantity**:
#     - Prioritize high-rated content with strong IMDb and TMDb scores to enhance user satisfaction and engagement.
#     - Promote hidden gems with fewer votes but high scores to increase visibility and attract new viewers.
#
# 5. **Data-Driven Marketing**:
#     - Utilize correlations between IMDb and TMDb scores to streamline marketing strategies and highlight top-rated content across platforms.
#     - Analyze trends in release years to identify peak periods for content production and acquisition.
#
# 6. **Continuous Improvement**:
#     - Monitor correlations between runtime, seasons, and audience reception to refine episodic content strategies.
#     - Use multivariate analysis to identify interactions between scores, popularity, and genres for better decision-making.
#
# By implementing these strategies, the client can enhance user satisfaction, broaden the subscriber base, and drive sustainable subscription growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project analyzed Amazon Prime Video's content data to uncover insights that can drive business growth. Key findings include:
#
# 1. **Content Strategy**:
#     - Focus on high-rated genres like drama, thriller, and comedy.
#     - Diversify offerings by investing in underrepresented genres and emerging production countries.
#
# 2. **Audience Engagement**:
#     - Tailor content based on runtime preferences and age certifications.
#     - Promote hidden gems with high ratings but low visibility.
#
# 3. **Data-Driven Decisions**:
#     - Leverage correlations between IMDb and TMDb scores for marketing.
#     - Optimize content acquisition by targeting high-performing release years and production countries.
#
# By implementing these insights, Amazon Prime Video can enhance user satisfaction, broaden its audience base, and achieve sustainable subscription growth.
